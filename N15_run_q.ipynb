# %%
import mcba
mcba.__file__
# Out:
# '/home/br/sweethome/1Dimpur/mcba_sandbox/mcba/__init__.py'

# %%
# !echo $PYTHONPATH
# Out:
# /home/br/sweethome/1Dimpur/mcba_sandbox/

# %%
# %matplotlib notebook

import numpy as np
import scipy.linalg as linalg
import matplotlib.pyplot as plt

import pandas as pd

# %%
from mcba.walker import Walker
from mcba.models.impurity import Par, SingleImpurity
from mcba.models.impurity import gamma, initial_q, k_F, E_FS, E_in, energy

for m in range(0, 12+4, 4):
    par = Par(N=15, L=45, m_q=m)
    model = SingleImpurity(par)

    #run MC
    walker = Walker(model, db_fname='N15mq%s.sqlite'%m)
    walker.walk()
# Out:
#  *** checkpointing, do NOT terminate...done
#
# ***************** sweeps =  42 	( 16  steps each)
# Par: N = 15,  L = 45,  V = 1.00,  gamma = 3.00
#      m_q = 0,  q = 0.00,  k_F = 1.05,  a = 0.089
# total cnf count =  295 rcache size =  0
# \sum |<FS|fq>|^2 = 0.9512
# \sum  <fq | P_up | fq> = -0.007156
# self.fs_pairs =  fsPairs(h=[-7, 7], p=[-10, 8])
# addr/acpt:
# 	 create/annihilate_pair:  0.39 / 0.016
# 	 move_fs_hole:  0.31 / 0.12
# 	 move_fs_particle:  0.31 / 0.14
# 	 umklapp_hole:  0.095 / 0.043
# 	 umkl_scatter:  0.14 / 0.04
# 	 scatter_hp:  0.18 / 0.12
# 	 scatter_pp:  0.2 / 0.1
# 	 scatter_hh:  0.12 / 0.04
#
#
#
#  *** checkpointing, do NOT terminate...done
#
# ***************** sweeps =  84 	( 16  steps each)
# Par: N = 15,  L = 45,  V = 1.00,  gamma = 3.00
#      m_q = 0,  q = 0.00,  k_F = 1.05,  a = 0.089
# total cnf count =  941 rcache size =  0
# \sum |<FS|fq>|^2 = 0.9666
# \sum  <fq | P_up | fq> = -0.004819
# self.fs_pairs =  fsPairs(h=[-8, 6], p=[9, -10])
# ...

# %%
for m in range(2, 12+4, 4):
    print(m)
# Out:
# 2
# 6
# 10
# 14

# %%
for m in range(1, 12+4, 4):
    par = Par(N=15, L=45, m_q=m)
    model = SingleImpurity(par)

    #run MC
    walker = Walker(model, db_fname='N15mq%s.sqlite'%m)
    walker.walk()
# Out:
#  *** checkpointing, do NOT terminate...done
#
# ***************** sweeps =  42 	( 16  steps each)
# Par: N = 15,  L = 45,  V = 1.00,  gamma = 3.00
#      m_q = 1,  q = 0.14,  k_F = 1.05,  a = 0.089
# total cnf count =  1 rcache size =  0
# \sum |<FS|fq>|^2 = 0.9152
# \sum  <fq | P_up | fq> = 0.1177
# self.fs_pairs =  fsPairs(h=[], p=[])
# addr/acpt:
# 	 create/annihilate_pair:  0.47 / 0.0
# 	 move_fs_hole:  0.0 / 0.0
# 	 move_fs_particle:  0.0 / 0.0
# 	 umklapp_hole:  0.0 / 0.0
# 	 umkl_scatter:  0.0 / 0.0
# 	 scatter_hp:  0.0 / 0.0
# 	 scatter_pp:  0.0 / 0.0
# 	 scatter_hh:  0.0 / 0.0
#
#
#
#  *** checkpointing, do NOT terminate...done
#
# ***************** sweeps =  84 	( 16  steps each)
# Par: N = 15,  L = 45,  V = 1.00,  gamma = 3.00
#      m_q = 1,  q = 0.14,  k_F = 1.05,  a = 0.089
# total cnf count =  11 rcache size =  0
# \sum |<FS|fq>|^2 = 0.9544
# \sum  <fq | P_up | fq> = 0.1142
# self.fs_pairs =  fsPairs(h=[], p=[])
# addr/acpt:
# 	 create/annihilate_pair:  0.47 / 0.006
# ...

# %%
for m in range(2, 12+4, 4):
    par = Par(N=15, L=45, m_q=m)
    model = SingleImpurity(par)

    #run MC
    walker = Walker(model, db_fname='N15mq%s.sqlite'%m)
    walker.walk()
# Out:
#  *** checkpointing, do NOT terminate...done
#
# ***************** sweeps =  42 	( 16  steps each)
# Par: N = 15,  L = 45,  V = 1.00,  gamma = 3.00
#      m_q = 2,  q = 0.28,  k_F = 1.05,  a = 0.089
# total cnf count =  16 rcache size =  0
# \sum |<FS|fq>|^2 = 0.9641
# \sum  <fq | P_up | fq> = 0.2361
# self.fs_pairs =  fsPairs(h=[6], p=[13])
# addr/acpt:
# 	 create/annihilate_pair:  0.39 / 0.006
# 	 move_fs_hole:  0.074 / 0.0074
# 	 move_fs_particle:  0.095 / 0.016
# 	 umklapp_hole:  0.0 / 0.0
# 	 umkl_scatter:  0.0 / 0.0
# 	 scatter_hp:  0.024 / 0.018
# 	 scatter_pp:  0.0 / 0.0
# 	 scatter_hh:  0.0 / 0.0
#
#
#
#  *** checkpointing, do NOT terminate...done
#
# ***************** sweeps =  84 	( 16  steps each)
# Par: N = 15,  L = 45,  V = 1.00,  gamma = 3.00
#      m_q = 2,  q = 0.28,  k_F = 1.05,  a = 0.089
# total cnf count =  421 rcache size =  0
# \sum |<FS|fq>|^2 = 0.9822
# \sum  <fq | P_up | fq> = 0.2355
# self.fs_pairs =  fsPairs(h=[-8, 1], p=[-10, 9])
# addr/acpt:
# ...

# %%
for m in range(3, 15, 4):
    par = Par(N=15, L=45, m_q=m)
    model = SingleImpurity(par)

    #run MC
    walker = Walker(model, db_fname='N15mq%s.sqlite'%m)
    walker.walk()
# Out:
#  *** checkpointing, do NOT terminate...done
#
# ***************** sweeps =  42 	( 16  steps each)
# Par: N = 15,  L = 45,  V = 1.00,  gamma = 3.00
#      m_q = 3,  q = 0.42,  k_F = 1.05,  a = 0.089
# total cnf count =  39 rcache size =  0
# \sum |<FS|fq>|^2 = 0.9661
# \sum  <fq | P_up | fq> = 0.3401
# self.fs_pairs =  fsPairs(h=[7], p=[8])
# addr/acpt:
# 	 create/annihilate_pair:  0.38 / 0.0089
# 	 move_fs_hole:  0.26 / 0.095
# 	 move_fs_particle:  0.23 / 0.082
# 	 umklapp_hole:  0.033 / 0.0074
# 	 umkl_scatter:  0.006 / 0.006
# 	 scatter_hp:  0.082 / 0.074
# 	 scatter_pp:  0.0 / 0.0
# 	 scatter_hh:  0.0 / 0.0
#
#
#
#  *** checkpointing, do NOT terminate...done
#
# ***************** sweeps =  84 	( 16  steps each)
# Par: N = 15,  L = 45,  V = 1.00,  gamma = 3.00
#      m_q = 3,  q = 0.42,  k_F = 1.05,  a = 0.089
# total cnf count =  279 rcache size =  0
# \sum |<FS|fq>|^2 = 0.9741
# \sum  <fq | P_up | fq> = 0.3399
# self.fs_pairs =  fsPairs(h=[-8, -2], p=[-10, 9])
# addr/acpt:
# ...

# %%
for m in [11]:
    par = Par(N=15, L=45, m_q=m)
    model = SingleImpurity(par)

    #run MC
    walker = Walker(model, db_fname='N15mq%s.sqlite'%m)
    walker.walk()
# Out:
# reading the DB...
# ...done
# checking  fsPairs(h=[-6, 1], p=[-9, 15])  ...ok
# checking  fsPairs(h=[-1, 7], p=[-20, 30])  ...ok
# checking  fsPairs(h=[-8, -7], p=[-13, 15])  ...ok
# checking  fsPairs(h=[-7, -2], p=[-10, 14])  ...ok
# checking  fsPairs(h=[-8, 5], p=[-13, 16])  ...ok
# checking  fsPairs(h=[3, 7], p=[-12, 26])  ...ok
# checking  fsPairs(h=[3, 7], p=[-15, 29])  ...ok
# checking  fsPairs(h=[-8, 7], p=[-91, 108])  ...ok
# checking  fsPairs(h=[-8, 5], p=[-39, 54])  ...ok
# checking  fsPairs(h=[1, 3], p=[-10, 21])  ...ok
#
# loading the cache...done. Start w/  3597  entries.
#
#  *** checkpointing, do NOT terminate...done
#
# ***************** sweeps =  42 	( 16  steps each)
# Par: N = 15,  L = 45,  V = 1.00,  gamma = 3.00
#      m_q = 11,  q = 1.54,  k_F = 1.05,  a = 0.089
# total cnf count =  3820 rcache size =  0
# \sum |<FS|fq>|^2 = 0.9921
# \sum  <fq | P_up | fq> = 0.6064
# self.fs_pairs =  fsPairs(h=[-8, -3], p=[-23, 29])
# addr/acpt:
# ...
